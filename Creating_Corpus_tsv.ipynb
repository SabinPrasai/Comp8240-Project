# %%
import pandas as pd

# Step 1: Read the text file and create a dictionary
data_dict = {}

with open("/content/sample_data/URLs.txt", "r") as file:
    lines = file.readlines()
    lines

# %%
print(lines)
# Out:
# ['https://www.nytimes.com/ - Left-Center Bias - High\n', 'https://www.cnn.com/ - Left Bias - High\n', 'https://www.bbc.com/news - extreme bias - High\n', 'https://www.theguardian.com/ - Left-Center Bias - High\n', 'https://www.reuters.com/ - Least Biased - High\n', 'https://www.washingtonpost.com/ - Left-Center Bias - High\n', 'https://www.aljazeera.com/ - Left-Center Bias - High\n', 'https://www.npr.org/ - Left-Center Bias - High\n', 'https://www.wsj.com/ - Right-Center Bias - High\n', 'https://www.cnbc.com/ - Left-Center Bias - High\n', 'https://news.google.com/home?gl=US&hl=en-US&ceid=US:en - slight to moderate liberal bias - High\n', 'https://www.foxnews.com/ - extreme bias - High\n', 'https://www.nbcnews.com/ - Left-Center Bias - High\n', 'https://www.huffpost.com/ - Left Bias - High\n', 'https://www.usatoday.com/ - Left-Center Bias - High\n', 'https://www.politico.com/ - Left-Center Bias - High\n', 'https://au.news.yahoo.com/ - Left-Center Bias - High\n', 'https://www.latimes.com/ - Left-Center Bias - High\n', 'https://www.newsmax.com/ - extreme bias - High\n', 'https://nypost.com/ - Right-Center Bias - High\n', 'https://www.abc.net.au/news - Left Biased - High\n', 'https://www.breitbart.com/news/ - Left-Center Bias - High\n', 'https://www.newsweek.com/ - Right-Center Bias - High\n', 'https://www.chicagotribune.com/ - Right-Center Bias - High\n', 'https://www.salon.com/ - Left Bias - High\n', 'https://www.boston.com/ - LEFT-CENTER BIAS - High\n', 'https://www.seattletimes.com/ - Left-Center Bias - High\n', 'https://www.mercurynews.com/news/weather/ - Least Biased - High\n', 'https://ktla.com/ - Least Biased - High\n', 'https://www.washingtontimes.com/ - extreme bias - High\n', 'https://chicago.suntimes.com/ - Left-Center Bias - High\n', 'https://theintercept.com/ - Left-Center Bias - High\n', 'https://abc13.com/ - Left-Center Bias - High\n', 'https://www.kxan.com/ - LEAST BIASED - High\n', 'https://gothamist.com/ - Left-Center Bias - High\n', 'https://www.laweekly.com/ - LEFT BIAS - High\n', 'https://www.theguardian.com/observer - Least Biased - High\n', 'https://www.kron4.com/ - LEAST BIASED- High\n', 'https://www.bostonherald.com/ - Right-Center Bias - High\n', 'https://www.autonews.com/ - Least Biased - High\n', 'https://www.phillyvoice.com/ - LEFT-CENTER BIAS - High\n']

# %%
splitted_text = []
for line in lines:
  list_line = line.split(" - ")
  splitted_text.append(list_line)

# %%
for split in splitted_text:
  count = len(split)
  if count == 2:
    print(split)
# Out:
# ['https://www.kron4.com/', 'LEAST BIASED- High\n']

# %%
splitted_text[0]
# Out:
# ['https://www.nytimes.com/', 'Left-Center Bias', 'High\n']

# %%
import re
def get_each_line_dict(split):
  # Define the regular expression pattern
  pattern = r'\d+\.'
  # Find all matches in the string
  matches = re.findall(pattern, str(split[0]))
  # Remove the matches from the string
  output_string = re.sub(pattern, '',str(split[0]))

  url = output_string.replace(" ",'')
  print(url)
  bias = split[1]
  fact = split[2].replace("\n",'')

  normalized_url = url.replace("https://", "").replace("www.", "")
  print(normalized_url)
  ref = "https://mediabiasfactcheck.com/" + normalized_url.replace(".com", "")
  print(ref)
  return {"source_url": url, "Normalized_url": normalized_url, "fact" : fact ,  "bias" : bias, "reference" : ref}

# %%
get_each_line_dict(splitted_text[0])
# Out:
# https://www.nytimes.com/
# nytimes.com/
# https://mediabiasfactcheck.com/nytimes/
# {'source_url': 'https://www.nytimes.com/',
#  'Normalized_url': 'nytimes.com/',
#  'fact': 'High',
#  'bias': 'Left-Center Bias',
#  'reference': 'https://mediabiasfactcheck.com/nytimes/'}

# %%
data_dict  = []
errorlist = []
count = 0
for split in splitted_text:
  try:
    line_dict = get_each_line_dict(split)
    data_dict.append(line_dict)
  except:
    errorlist.append(count)
  count+=1
# Out:
# https://www.nytimes.com/
# nytimes.com/
# https://mediabiasfactcheck.com/nytimes/
# https://www.cnn.com/
# cnn.com/
# https://mediabiasfactcheck.com/cnn/
# https://www.bbc.com/news
# bbc.com/news
# https://mediabiasfactcheck.com/bbc/news
# https://www.theguardian.com/
# theguardian.com/
# https://mediabiasfactcheck.com/theguardian/
# https://www.reuters.com/
# reuters.com/
# https://mediabiasfactcheck.com/reuters/
# https://www.washingtonpost.com/
# washingtonpost.com/
# https://mediabiasfactcheck.com/washingtonpost/
# https://www.aljazeera.com/
# aljazeera.com/
# https://mediabiasfactcheck.com/aljazeera/
# https://www.npr.org/
# npr.org/
# https://mediabiasfactcheck.com/npr.org/
# https://www.wsj.com/
# wsj.com/
# https://mediabiasfactcheck.com/wsj/
# https://www.cnbc.com/
# cnbc.com/
# https://mediabiasfactcheck.com/cnbc/
# https://news.google.com/home?gl=US&hl=en-US&ceid=US:en
# news.google.com/home?gl=US&hl=en-US&ceid=US:en
# https://mediabiasfactcheck.com/news.google/home?gl=US&hl=en-US&ceid=US:en
# https://www.foxnews.com/
# foxnews.com/
# https://mediabiasfactcheck.com/foxnews/
# https://www.nbcnews.com/
# nbcnews.com/
# https://mediabiasfactcheck.com/nbcnews/
# https://www.huffpost.com/
# huffpost.com/
# https://mediabiasfactcheck.com/huffpost/
# https://www.usatoday.com/
# usatoday.com/
# https://mediabiasfactcheck.com/usatoday/
# https://www.politico.com/
# politico.com/
# https://mediabiasfactcheck.com/politico/
# https://au.news.yahoo.com/
# au.news.yahoo.com/
# https://mediabiasfactcheck.com/au.news.yahoo/
# https://www.latimes.com/
# latimes.com/
# https://mediabiasfactcheck.com/latimes/
# https://www.newsmax.com/
# newsmax.com/
# https://mediabiasfactcheck.com/newsmax/
# https://nypost.com/
# nypost.com/
# https://mediabiasfactcheck.com/nypost/
# https://www.abc.net.au/news
# abc.net.au/news
# https://mediabiasfactcheck.com/abc.net.au/news
# https://www.breitbart.com/news/
# breitbart.com/news/
# https://mediabiasfactcheck.com/breitbart/news/
# https://www.newsweek.com/
# newsweek.com/
# https://mediabiasfactcheck.com/newsweek/
# https://www.chicagotribune.com/
# chicagotribune.com/
# https://mediabiasfactcheck.com/chicagotribune/
# https://www.salon.com/
# salon.com/
# https://mediabiasfactcheck.com/salon/
# https://www.boston.com/
# boston.com/
# https://mediabiasfactcheck.com/boston/
# https://www.seattletimes.com/
# seattletimes.com/
# https://mediabiasfactcheck.com/seattletimes/
# https://www.mercurynews.com/news/weather/
# mercurynews.com/news/weather/
# https://mediabiasfactcheck.com/mercurynews/news/weather/
# https://ktla.com/
# ktla.com/
# https://mediabiasfactcheck.com/ktla/
# https://www.washingtontimes.com/
# washingtontimes.com/
# https://mediabiasfactcheck.com/washingtontimes/
# https://chicago.suntimes.com/
# chicago.suntimes.com/
# https://mediabiasfactcheck.com/chicago.suntimes/
# https://theintercept.com/
# theintercept.com/
# https://mediabiasfactcheck.com/theintercept/
# https://abccom/
# abccom/
# https://mediabiasfactcheck.com/abccom/
# https://www.kxan.com/
# kxan.com/
# https://mediabiasfactcheck.com/kxan/
# https://gothamist.com/
# gothamist.com/
# https://mediabiasfactcheck.com/gothamist/
# https://www.laweekly.com/
# laweekly.com/
# https://mediabiasfactcheck.com/laweekly/
# https://www.theguardian.com/observer
# theguardian.com/observer
# https://mediabiasfactcheck.com/theguardian/observer
# https://www.kroncom/
# https://www.bostonherald.com/
# bostonherald.com/
# https://mediabiasfactcheck.com/bostonherald/
# https://www.autonews.com/
# autonews.com/
# https://mediabiasfactcheck.com/autonews/
# https://www.phillyvoice.com/
# phillyvoice.com/
# https://mediabiasfactcheck.com/phillyvoice/

# %%
errorlist
# Out:
# [37]

# %%
import csv

# Specify the output file path
output_file = 'corpus.tsv'

# Extract column names from the first dictionary
column_names = data_dict[0].keys()

# Write the data to a TSV file
with open(output_file, mode='w+', newline='') as tsv_file:
    writer = csv.DictWriter(tsv_file, fieldnames=column_names, delimiter='\t')

    # Write the header
    writer.writeheader()

    # Write the data rows
    for row in data_dict:
        writer.writerow(row)

print(f"Data has been written to {output_file}.")
# Out:
# Data has been written to corpus.tsv.

# %%
import pandas as pd
read_df = pd.read_csv('/content/corpus.tsv', sep='\t')
read_df
# Out:
#                                            source_url  \
# 0                            https://www.nytimes.com/
# 1                                https://www.cnn.com/
# 2                            https://www.bbc.com/news
# 3                        https://www.theguardian.com/
# 4                            https://www.reuters.com/
# 5                     https://www.washingtonpost.com/
# 11                     extreme bias
# 12                 Left-Center Bias
# 13                        Left Bias
# 14                 Left-Center Bias
# 15                 Left-Center Bias
# 16                 Left-Center Bias
# 17                 Left-Center Bias
# 18                     extreme bias
# 19                Right-Center Bias
# 20                      Left Biased
# 21                 Left-Center Bias
# 22                Right-Center Bias
# 23                Right-Center Bias
# 24                        Left Bias
# 25                 LEFT-CENTER BIAS
# 26                 Left-Center Bias
# 27                     Least Biased
# 28                     Least Biased
# 29                     extreme bias
# 30                 Left-Center Bias
# 31                 Left-Center Bias
# 32                 Left-Center Bias
# 33                     LEAST BIASED
# 34                 Left-Center Bias
# 35                        LEFT BIAS
# 36                     Least Biased
# 37                Right-Center Bias
# 38                     Least Biased
# 39                 LEFT-CENTER BIAS
#
#                                             reference
# 0             https://mediabiasfactcheck.com/nytimes/
# 1                 https://mediabiasfactcheck.com/cnn/
# 2             https://mediabiasfactcheck.com/bbc/news
# 3         https://mediabiasfactcheck.com/theguardian/
# 4             https://mediabiasfactcheck.com/reuters/
# 5      https://mediabiasfactcheck.com/washingtonpost/
# 6           https://mediabiasfactcheck.com/aljazeera/
# 7             https://mediabiasfactcheck.com/npr.org/
# 8                 https://mediabiasfactcheck.com/wsj/
# 9                https://mediabiasfactcheck.com/cnbc/
# 10  https://mediabiasfactcheck.com/news.google/hom...
# 11            https://mediabiasfactcheck.com/foxnews/
# 12            https://mediabiasfactcheck.com/nbcnews/
# 13           https://mediabiasfactcheck.com/huffpost/
# 14           https://mediabiasfactcheck.com/usatoday/
# 15           https://mediabiasfactcheck.com/politico/
# 16      https://mediabiasfactcheck.com/au.news.yahoo/
# 17            https://mediabiasfactcheck.com/latimes/
# 18            https://mediabiasfactcheck.com/newsmax/
# 19             https://mediabiasfactcheck.com/nypost/
# 20     https://mediabiasfactcheck.com/abc.net.au/news
# 21     https://mediabiasfactcheck.com/breitbart/news/
# 22           https://mediabiasfactcheck.com/newsweek/
# 23     https://mediabiasfactcheck.com/chicagotribune/
# 24              https://mediabiasfactcheck.com/salon/
# 25             https://mediabiasfactcheck.com/boston/
# 26       https://mediabiasfactcheck.com/seattletimes/
# 27  https://mediabiasfactcheck.com/mercurynews/new...
# 28               https://mediabiasfactcheck.com/ktla/
# 29    https://mediabiasfactcheck.com/washingtontimes/
# 30   https://mediabiasfactcheck.com/chicago.suntimes/
# 31       https://mediabiasfactcheck.com/theintercept/
# 32             https://mediabiasfactcheck.com/abccom/
# 33               https://mediabiasfactcheck.com/kxan/
# 34          https://mediabiasfactcheck.com/gothamist/
# 35           https://mediabiasfactcheck.com/laweekly/
# 36  https://mediabiasfactcheck.com/theguardian/obs...
# 37       https://mediabiasfactcheck.com/bostonherald/
# 38           https://mediabiasfactcheck.com/autonews/
# 39        https://mediabiasfactcheck.com/phillyvoice/
